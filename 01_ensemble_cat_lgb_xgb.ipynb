# %% [markdown]
# # Ensemble: CatBoost + LightGBM + XGBoost (with Geohash Decoding)
# **Goal:** Maximum accuracy using spatial features + 3-model weighted ensemble with **5-Fold Cross-Validation**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans
from catboost import CatBoostRegressor
import lightgbm as lgb
import xgboost as xgb

# %% [markdown]
# ## 1. Geohash Decoder (no external library needed)

# %%
_BASE32 = '0123456789bcdefghjkmnpqrstuvwxyz'
_BASE32_MAP = {c: i for i, c in enumerate(_BASE32)}

def decode_geohash(gh):
    """Decode a geohash string to (latitude, longitude)."""
    lat_range = [-90.0, 90.0]
    lon_range = [-180.0, 180.0]
    is_lon = True
    
    for char in gh:
        val = _BASE32_MAP[char]
        for bit in [16, 8, 4, 2, 1]:
            if is_lon:
                mid = (lon_range[0] + lon_range[1]) / 2
                if val & bit:
                    lon_range[0] = mid
                else:
                    lon_range[1] = mid
            else:
                mid = (lat_range[0] + lat_range[1]) / 2
                if val & bit:
                    lat_range[0] = mid
                else:
                    lat_range[1] = mid
            is_lon = not is_lon
    
    lat = (lat_range[0] + lat_range[1]) / 2
    lon = (lon_range[0] + lon_range[1]) / 2
    return lat, lon

# Quick test
print("qp02z1 ->", decode_geohash('qp02z1'))
print("qp02zt ->", decode_geohash('qp02zt'))
# Out:
# qp02z1 -> (-5.48492431640625, 90.6646728515625)
# qp02zt -> (-5.46295166015625, 90.6866455078125)

# %% [markdown]
# ## 2. Load Data

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")
print("Train:", train_df.shape, "| Test:", test_df.shape)
# Out:
# Train: (77299, 11) | Test: (41778, 10)

# %% [markdown]
# ## 3. Feature Engineering

# %%
def engineer_features(df):
    df = df.copy()
    
    # ---- GEOHASH -> SPATIAL FEATURES ----
    coords = df['geohash'].apply(decode_geohash)
    df['latitude'] = coords.apply(lambda x: x[0])
    df['longitude'] = coords.apply(lambda x: x[1])
    
    # Prefix hierarchy
    df['gh_prefix_3'] = df['geohash'].str[:3]
    df['gh_prefix_4'] = df['geohash'].str[:4]
    df['gh_prefix_5'] = df['geohash'].str[:5]
    
    # ---- POLYNOMIAL SPATIAL INTERACTIONS ----
    df['lat_squared'] = df['latitude'] ** 2
    df['lon_squared'] = df['longitude'] ** 2
    df['lat_lon_interaction'] = df['latitude'] * df['longitude']
    
    # ---- DISTANCE FROM CENTROID ----
    lat_center = df['latitude'].mean()
    lon_center = df['longitude'].mean()
    df['dist_from_center'] = np.sqrt(
        (df['latitude'] - lat_center) ** 2 + (df['longitude'] - lon_center) ** 2
    )
    
    # ---- TIME FEATURES ----
    df['hour'] = df['timestamp'].apply(lambda x: int(x.split(':')[0]))
    df['minute'] = df['timestamp'].apply(lambda x: int(x.split(':')[1]))
    df['time_slot'] = df['hour'] * 4 + df['minute'] // 15
    
    df['hour_sin'] = np.sin(2 * np.pi * df['hour'] / 24)
    df['hour_cos'] = np.cos(2 * np.pi * df['hour'] / 24)
    
    df['is_peak'] = df['hour'].apply(lambda h: 1 if h in [7,8,9,17,18,19] else 0)
    
    # ---- IMPUTE MISSING ----
    df['RoadType'].fillna('Residential', inplace=True)
    df['Weather'].fillna('Sunny', inplace=True)
    df['Temperature'].fillna(df['Temperature'].median(), inplace=True)
    
    df.drop('timestamp', axis=1, inplace=True)
    return df

# Combine train + test for consistent encoding
train_df['is_train'] = 1
test_df['is_train'] = 0
test_df['demand'] = np.nan

combined = pd.concat([train_df, test_df], axis=0, ignore_index=True)
combined = engineer_features(combined)

# ---- KMEANS SPATIAL CLUSTERS ----
N_CLUSTERS = 8
kmeans = KMeans(n_clusters=N_CLUSTERS, random_state=42, n_init=10)
combined['spatial_cluster'] = kmeans.fit_predict(combined[['latitude', 'longitude']])
print(f"Created {N_CLUSTERS} spatial clusters")
print("Cluster distribution:\n", combined['spatial_cluster'].value_counts().sort_index())

# Label encode ALL categorical columns (spatial_cluster included)
cat_col_names = ['geohash', 'RoadType', 'LargeVehicles', 'Landmarks', 'Weather',
                 'gh_prefix_3', 'gh_prefix_4', 'gh_prefix_5', 'spatial_cluster']
for col in cat_col_names:
    le = LabelEncoder()
    combined[col] = le.fit_transform(combined[col].astype(str))

# Split back
train_processed = combined[combined['is_train'] == 1].drop('is_train', axis=1).reset_index(drop=True)
test_processed = combined[combined['is_train'] == 0].drop(['is_train', 'demand'], axis=1).reset_index(drop=True)

print("\nTrain processed:", train_processed.shape)
print("Test processed:", test_processed.shape)
print("\nColumns:", list(train_processed.columns))
# Out:
# C:\Users\byard\AppData\Local\Temp\ipykernel_16192\565341829.py:37: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['RoadType'].fillna('Residential', inplace=True)
# C:\Users\byard\AppData\Local\Temp\ipykernel_16192\565341829.py:38: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Weather'].fillna('Sunny', inplace=True)
# C:\Users\byard\AppData\Local\Temp\ipykernel_16192\565341829.py:39: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Temperature'].fillna(df['Temperature'].median(), inplace=True)
# Created 8 spatial clusters
# Cluster distribution:
#  spatial_cluster
# 0    14072
# 1    14029
# 2    15124
# 3    16951
# 4    12660
# 5    12006
# 6    16087
# 7    18148
# Name: count, dtype: int64
#
# Train processed: (77299, 26)
# Test processed: (41778, 25)
#
# Columns: ['Index', 'geohash', 'day', 'demand', 'RoadType', 'NumberofLanes', 'LargeVehicles', 'Landmarks', 'Temperature', 'Weather', 'latitude', 'longitude', 'gh_prefix_3', 'gh_prefix_4', 'gh_prefix_5', 'lat_squared', 'lon_squared', 'lat_lon_interaction', 'dist_from_center', 'hour', 'minute', 'time_slot', 'hour_sin', 'hour_cos', 'is_peak', 'spatial_cluster']

# %%
drop_cols = ['demand', 'Index']
feature_cols = [c for c in train_processed.columns if c not in drop_cols]

X = train_processed[feature_cols]
y = train_processed['demand']
X_test_final = test_processed[feature_cols]

# Show the new spatial features
spatial_feats = ['latitude', 'longitude', 'lat_squared', 'lon_squared',
                 'lat_lon_interaction', 'dist_from_center', 'spatial_cluster']
print(f"Full training set: {X.shape}")
print(f"Test set: {X_test_final.shape}")
print(f"\nAll features ({len(feature_cols)}): {feature_cols}")
print(f"\nNew spatial features: {spatial_feats}")
# Out:
# Full training set: (77299, 24)
# Test set: (41778, 24)
#
# All features (24): ['geohash', 'day', 'RoadType', 'NumberofLanes', 'LargeVehicles', 'Landmarks', 'Temperature', 'Weather', 'latitude', 'longitude', 'gh_prefix_3', 'gh_prefix_4', 'gh_prefix_5', 'lat_squared', 'lon_squared', 'lat_lon_interaction', 'dist_from_center', 'hour', 'minute', 'time_slot', 'hour_sin', 'hour_cos', 'is_peak', 'spatial_cluster']
#
# New spatial features: ['latitude', 'longitude', 'lat_squared', 'lon_squared', 'lat_lon_interaction', 'dist_from_center', 'spatial_cluster']

# %% [markdown]
# ## 4. 5-Fold Cross-Validation (CatBoost + LightGBM + XGBoost)
#
# Each fold:
# 1. Trains all 3 models on the training split
# 2. Stores out-of-fold (OOF) predictions for proper evaluation
# 3. Predicts on the test set (averaged across all folds)

# %%
N_FOLDS = 5
kf = KFold(n_splits=N_FOLDS, shuffle=True, random_state=42)

# OOF prediction arrays
oof_cat = np.zeros(len(X))
oof_lgb = np.zeros(len(X))
oof_xgb = np.zeros(len(X))

# Test predictions (accumulated across folds, then averaged)
test_cat = np.zeros(len(X_test_final))
test_lgb = np.zeros(len(X_test_final))
test_xgb = np.zeros(len(X_test_final))

# Per-fold metrics
fold_metrics = []

for fold_idx, (train_idx, val_idx) in enumerate(kf.split(X), 1):
    print(f"\n{'='*70}")
    print(f"  FOLD {fold_idx}/{N_FOLDS}  |  Train: {len(train_idx)}  |  Val: {len(val_idx)}")
    print(f"{'='*70}")
    
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
    
    # ---- CatBoost ----
    print("\n--- CatBoost ---")
    cat_model = CatBoostRegressor(
        iterations=2000,
        learning_rate=0.05,
        depth=6,
        loss_function="RMSE",
        cat_features=cat_col_names,
        verbose=200
    )
    cat_model.fit(X_train, y_train, eval_set=(X_val, y_val), early_stopping_rounds=100)
    oof_cat[val_idx] = cat_model.predict(X_val)
    test_cat += cat_model.predict(X_test_final) / N_FOLDS
    
    # ---- LightGBM ----
    print("\n--- LightGBM ---")
    lgb_train = lgb.Dataset(X_train, label=y_train, categorical_feature=cat_col_names)
    lgb_val_ds = lgb.Dataset(X_val, label=y_val, categorical_feature=cat_col_names, reference=lgb_train)
    
    lgb_params = {
        'objective': 'regression',
        'metric': 'rmse',
        'boosting_type': 'gbdt',
        'learning_rate': 0.05,
        'num_leaves': 127,
        'min_child_samples': 20,
        'feature_fraction': 0.8,
        'bagging_fraction': 0.8,
        'bagging_freq': 5,
        'verbose': -1
    }
    
    lgb_model = lgb.train(
        lgb_params, lgb_train,
        num_boost_round=2000,
        valid_sets=[lgb_train, lgb_val_ds],
        valid_names=['train', 'val'],
        callbacks=[lgb.log_evaluation(200), lgb.early_stopping(100)]
    )
    oof_lgb[val_idx] = lgb_model.predict(X_val)
    test_lgb += lgb_model.predict(X_test_final) / N_FOLDS
    
    # ---- XGBoost ----
    print("\n--- XGBoost ---")
    xgb_model = xgb.XGBRegressor(
        n_estimators=2000,
        learning_rate=0.05,
        max_depth=6,
        subsample=0.8,
        colsample_bytree=0.8,
        min_child_weight=5,
        tree_method='hist',
        early_stopping_rounds=100,
        eval_metric='rmse',
        verbosity=0
    )
    xgb_model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=200)
    oof_xgb[val_idx] = xgb_model.predict(X_val)
    test_xgb += xgb_model.predict(X_test_final) / N_FOLDS
    
    # ---- Fold metrics ----
    cat_rmse_f = np.sqrt(mean_squared_error(y_val, oof_cat[val_idx]))
    lgb_rmse_f = np.sqrt(mean_squared_error(y_val, oof_lgb[val_idx]))
    xgb_rmse_f = np.sqrt(mean_squared_error(y_val, oof_xgb[val_idx]))
    cat_r2_f = r2_score(y_val, oof_cat[val_idx])
    lgb_r2_f = r2_score(y_val, oof_lgb[val_idx])
    xgb_r2_f = r2_score(y_val, oof_xgb[val_idx])
    
    fold_metrics.append({
        'fold': fold_idx,
        'cat_rmse': cat_rmse_f, 'cat_r2': cat_r2_f,
        'lgb_rmse': lgb_rmse_f, 'lgb_r2': lgb_r2_f,
        'xgb_rmse': xgb_rmse_f, 'xgb_r2': xgb_r2_f
    })
    
    print(f"\n  Fold {fold_idx} Summary:")
    print(f"    CatBoost  -> RMSE: {cat_rmse_f:.6f} | R2: {cat_r2_f:.6f}")
    print(f"    LightGBM  -> RMSE: {lgb_rmse_f:.6f} | R2: {lgb_r2_f:.6f}")
    print(f"    XGBoost   -> RMSE: {xgb_rmse_f:.6f} | R2: {xgb_r2_f:.6f}")

print(f"\n{'='*70}")
print("  5-FOLD CROSS-VALIDATION COMPLETE")
print(f"{'='*70}")
# Out:
# ======================================================================
#   FOLD 1/5  |  Train: 61839  |  Val: 15460
# ======================================================================
#
# --- CatBoost ---
# 0:	learn: 0.1367733	test: 0.1367257	best: 0.1367257 (0)	total: 193ms	remaining: 6m 25s
# 200:	learn: 0.0416525	test: 0.0409903	best: 0.0409903 (198)	total: 9.03s	remaining: 1m 20s
# 400:	learn: 0.0384668	test: 0.0383559	best: 0.0383559 (400)	total: 18.3s	remaining: 1m 12s
# 600:	learn: 0.0362964	test: 0.0365830	best: 0.0365830 (600)	total: 27.8s	remaining: 1m 4s
# 800:	learn: 0.0345907	test: 0.0352265	best: 0.0352265 (800)	total: 37s	remaining: 55.4s
# 1000:	learn: 0.0333448	test: 0.0342995	best: 0.0342995 (1000)	total: 46.2s	remaining: 46.1s
# 1200:	learn: 0.0322709	test: 0.0335158	best: 0.0335158 (1200)	total: 55.4s	remaining: 36.8s
# 1400:	learn: 0.0315135	test: 0.0330434	best: 0.0330434 (1400)	total: 1m 4s	remaining: 27.6s
# 1600:	learn: 0.0308408	test: 0.0326217	best: 0.0326217 (1600)	total: 1m 13s	remaining: 18.4s
# 1800:	learn: 0.0302983	test: 0.0322855	best: 0.0322855 (1800)	total: 1m 23s	remaining: 9.2s
# 1999:	learn: 0.0298010	test: 0.0319812	best: 0.0319806 (1997)	total: 1m 32s	remaining: 0us
#
# bestTest = 0.03198062658
# bestIteration = 1997
#
# Shrink model to first 1998 iterations.
#
# --- LightGBM ---
# Training until validation scores don't improve for 100 rounds
# [200]	train's rmse: 0.0236778	val's rmse: 0.0292873
# [400]	train's rmse: 0.0200433	val's rmse: 0.0285753
# [600]	train's rmse: 0.0178448	val's rmse: 0.0283071
# [800]	train's rmse: 0.0161428	val's rmse: 0.0282086
# [1000]	train's rmse: 0.0147125	val's rmse: 0.0281504
# Early stopping, best iteration is:
# [1050]	train's rmse: 0.0143985	val's rmse: 0.0281291
#
# --- XGBoost ---
# [0]	validation_0-rmse:0.13644
# [200]	validation_0-rmse:0.04503
# [400]	validation_0-rmse:0.03985
# [600]	validation_0-rmse:0.03714
# [800]	validation_0-rmse:0.03525
# [1000]	validation_0-rmse:0.03403
# [1200]	validation_0-rmse:0.03320
# [1400]	validation_0-rmse:0.03263
# [1600]	validation_0-rmse:0.03218
# [1800]	validation_0-rmse:0.03177
# [1999]	validation_0-rmse:0.03152
#
#   Fold 1 Summary:
#     CatBoost  -> RMSE: 0.031981 | R2: 0.949455
#     LightGBM  -> RMSE: 0.028129 | R2: 0.960896
#     XGBoost   -> RMSE: 0.031517 | R2: 0.950910
#
# ======================================================================
#   FOLD 2/5  |  Train: 61839  |  Val: 15460
# ======================================================================
#
# --- CatBoost ---
# 0:	learn: 0.1361034	test: 0.1395394	best: 0.1395394 (0)	total: 49.6ms	remaining: 1m 39s
# 200:	learn: 0.0422567	test: 0.0429675	best: 0.0429675 (200)	total: 8.15s	remaining: 1m 12s
# 400:	learn: 0.0383221	test: 0.0393218	best: 0.0393218 (400)	total: 16.7s	remaining: 1m 6s
# 600:	learn: 0.0360157	test: 0.0374661	best: 0.0374661 (600)	total: 25.3s	remaining: 59s
# 800:	learn: 0.0345066	test: 0.0363362	best: 0.0363362 (800)	total: 34s	remaining: 50.9s
# 1000:	learn: 0.0333076	test: 0.0354205	best: 0.0354205 (1000)	total: 42.7s	remaining: 42.7s
# 1200:	learn: 0.0322724	test: 0.0347067	best: 0.0347067 (1200)	total: 51.5s	remaining: 34.3s
# 1400:	learn: 0.0314622	test: 0.0341701	best: 0.0341694 (1397)	total: 1m	remaining: 25.9s
# 1600:	learn: 0.0307602	test: 0.0337315	best: 0.0337315 (1600)	total: 1m 9s	remaining: 17.4s
# 1800:	learn: 0.0302468	test: 0.0333860	best: 0.0333860 (1800)	total: 1m 18s	remaining: 8.7s
# 1999:	learn: 0.0298104	test: 0.0331456	best: 0.0331456 (1999)	total: 1m 27s	remaining: 0us
#
# bestTest = 0.03314564263
# bestIteration = 1999
#
#
# --- LightGBM ---
# Training until validation scores don't improve for 100 rounds
# [200]	train's rmse: 0.023565	val's rmse: 0.0300225
# [400]	train's rmse: 0.0201157	val's rmse: 0.0293696
# [600]	train's rmse: 0.0179108	val's rmse: 0.0291312
# [800]	train's rmse: 0.0161766	val's rmse: 0.0290213
# [1000]	train's rmse: 0.014753	val's rmse: 0.0289372
# Early stopping, best iteration is:
# [1039]	train's rmse: 0.0144915	val's rmse: 0.0289184
#
# --- XGBoost ---
# [0]	validation_0-rmse:0.13921
# [200]	validation_0-rmse:0.04596
# [400]	validation_0-rmse:0.04072
# [600]	validation_0-rmse:0.03794
# [800]	validation_0-rmse:0.03611
# [1000]	validation_0-rmse:0.03500
# [1200]	validation_0-rmse:0.03417
# [1400]	validation_0-rmse:0.03349
# [1600]	validation_0-rmse:0.03300
# [1800]	validation_0-rmse:0.03266
# [1999]	validation_0-rmse:0.03241
#
#   Fold 2 Summary:
#     CatBoost  -> RMSE: 0.033146 | R2: 0.947749
#     LightGBM  -> RMSE: 0.028918 | R2: 0.960227
#     XGBoost   -> RMSE: 0.032409 | R2: 0.950047
#
# ======================================================================
#   FOLD 3/5  |  Train: 61839  |  Val: 15460
# ======================================================================
#
# --- CatBoost ---
# 0:	learn: 0.1368309	test: 0.1366473	best: 0.1366473 (0)	total: 44.6ms	remaining: 1m 29s
# 200:	learn: 0.0411245	test: 0.0399167	best: 0.0399167 (200)	total: 8.38s	remaining: 1m 14s
# 400:	learn: 0.0375739	test: 0.0370742	best: 0.0370742 (400)	total: 17.2s	remaining: 1m 8s
# 600:	learn: 0.0354710	test: 0.0354566	best: 0.0354566 (600)	total: 26.5s	remaining: 1m 1s
# 800:	learn: 0.0339775	test: 0.0342331	best: 0.0342331 (800)	total: 35.3s	remaining: 52.8s
# 1000:	learn: 0.0328884	test: 0.0335004	best: 0.0335004 (1000)	total: 44.1s	remaining: 44s
# 1200:	learn: 0.0320384	test: 0.0329267	best: 0.0329267 (1200)	total: 52.9s	remaining: 35.2s
# 1400:	learn: 0.0313553	test: 0.0324844	best: 0.0324844 (1400)	total: 1m 2s	remaining: 26.5s
# 1600:	learn: 0.0307548	test: 0.0321080	best: 0.0321080 (1600)	total: 1m 10s	remaining: 17.7s
# 1800:	learn: 0.0302512	test: 0.0317941	best: 0.0317941 (1800)	total: 1m 19s	remaining: 8.81s
# 1999:	learn: 0.0298350	test: 0.0315831	best: 0.0315827 (1997)	total: 1m 28s	remaining: 0us
#
# bestTest = 0.03158269443
# bestIteration = 1997
#
# Shrink model to first 1998 iterations.
#
# --- LightGBM ---
# Training until validation scores don't improve for 100 rounds
# [200]	train's rmse: 0.0236107	val's rmse: 0.0296142
# [400]	train's rmse: 0.0201533	val's rmse: 0.0288444
# [600]	train's rmse: 0.0179417	val's rmse: 0.0286159
# [800]	train's rmse: 0.0161927	val's rmse: 0.0285151
# [1000]	train's rmse: 0.0147957	val's rmse: 0.0284375
# [1200]	train's rmse: 0.0135803	val's rmse: 0.028419
# Early stopping, best iteration is:
# [1107]	train's rmse: 0.0141118	val's rmse: 0.0284072
#
# --- XGBoost ---
# [0]	validation_0-rmse:0.13631
# [200]	validation_0-rmse:0.04461
# [400]	validation_0-rmse:0.03942
# [600]	validation_0-rmse:0.03663
# [800]	validation_0-rmse:0.03493
# [1000]	validation_0-rmse:0.03376
# [1200]	validation_0-rmse:0.03282
# [1400]	validation_0-rmse:0.03221
# [1600]	validation_0-rmse:0.03178
# [1800]	validation_0-rmse:0.03144
# [1999]	validation_0-rmse:0.03121
#
#   Fold 3 Summary:
#     CatBoost  -> RMSE: 0.031583 | R2: 0.950521
#     LightGBM  -> RMSE: 0.028407 | R2: 0.959971
#     XGBoost   -> RMSE: 0.031206 | R2: 0.951693
#
# ======================================================================
#   FOLD 4/5  |  Train: 61839  |  Val: 15460
# ======================================================================
#
# --- CatBoost ---
# 0:	learn: 0.1376570	test: 0.1331660	best: 0.1331660 (0)	total: 45.1ms	remaining: 1m 30s
# 200:	learn: 0.0411765	test: 0.0409306	best: 0.0409306 (200)	total: 8.11s	remaining: 1m 12s
# 400:	learn: 0.0377245	test: 0.0380419	best: 0.0380419 (400)	total: 16.3s	remaining: 1m 4s
# 600:	learn: 0.0355344	test: 0.0363948	best: 0.0363948 (600)	total: 25s	remaining: 58.2s
# 800:	learn: 0.0339662	test: 0.0352745	best: 0.0352745 (800)	total: 34s	remaining: 50.8s
# 1000:	learn: 0.0327802	test: 0.0344164	best: 0.0344164 (1000)	total: 42.9s	remaining: 42.8s
# 1200:	learn: 0.0319179	test: 0.0338653	best: 0.0338653 (1199)	total: 51.6s	remaining: 34.4s
# 1400:	learn: 0.0312324	test: 0.0334678	best: 0.0334678 (1400)	total: 1m	remaining: 25.9s
# 1600:	learn: 0.0306375	test: 0.0331531	best: 0.0331508 (1598)	total: 1m 9s	remaining: 17.3s
# 1800:	learn: 0.0301355	test: 0.0328950	best: 0.0328950 (1800)	total: 1m 18s	remaining: 8.68s
# 1999:	learn: 0.0296676	test: 0.0326590	best: 0.0326590 (1999)	total: 1m 27s	remaining: 0us
#
# bestTest = 0.0326590475
# bestIteration = 1999
#
#
# --- LightGBM ---
# Training until validation scores don't improve for 100 rounds
# [200]	train's rmse: 0.0236128	val's rmse: 0.030468
# [400]	train's rmse: 0.0200268	val's rmse: 0.029705
# [600]	train's rmse: 0.0177891	val's rmse: 0.0295073
# [800]	train's rmse: 0.0160782	val's rmse: 0.0294884
# [1000]	train's rmse: 0.0146977	val's rmse: 0.029448
# [1200]	train's rmse: 0.0135094	val's rmse: 0.0294217
# [1400]	train's rmse: 0.0124747	val's rmse: 0.029399
# Early stopping, best iteration is:
# [1342]	train's rmse: 0.0127572	val's rmse: 0.0293901
#
# --- XGBoost ---
# [0]	validation_0-rmse:0.13294
# [200]	validation_0-rmse:0.04521
# [400]	validation_0-rmse:0.04019
# [600]	validation_0-rmse:0.03746
# [800]	validation_0-rmse:0.03580
# [1000]	validation_0-rmse:0.03474
# [1200]	validation_0-rmse:0.03404
# [1400]	validation_0-rmse:0.03355
# [1600]	validation_0-rmse:0.03320
# [1800]	validation_0-rmse:0.03294
# [1999]	validation_0-rmse:0.03269
#
#   Fold 4 Summary:
#     CatBoost  -> RMSE: 0.032659 | R2: 0.944371
#     LightGBM  -> RMSE: 0.029390 | R2: 0.954950
#     XGBoost   -> RMSE: 0.032688 | R2: 0.944272
#
# ======================================================================
#   FOLD 5/5  |  Train: 61840  |  Val: 15459
# ======================================================================
#
# --- CatBoost ---
# 0:	learn: 0.1364950	test: 0.1376843	best: 0.1376843 (0)	total: 45.9ms	remaining: 1m 31s
# 200:	learn: 0.0410001	test: 0.0413140	best: 0.0413140 (200)	total: 8.28s	remaining: 1m 14s
# 400:	learn: 0.0374278	test: 0.0381439	best: 0.0381439 (400)	total: 16.9s	remaining: 1m 7s
# 600:	learn: 0.0353767	test: 0.0364101	best: 0.0364101 (600)	total: 25.8s	remaining: 1m
# 800:	learn: 0.0340233	test: 0.0352725	best: 0.0352725 (800)	total: 34.6s	remaining: 51.7s
# 1000:	learn: 0.0330199	test: 0.0344658	best: 0.0344658 (1000)	total: 43.2s	remaining: 43.1s
# 1200:	learn: 0.0320896	test: 0.0337801	best: 0.0337801 (1200)	total: 51.9s	remaining: 34.5s
# 1400:	learn: 0.0313660	test: 0.0332916	best: 0.0332916 (1400)	total: 1m	remaining: 25.9s
# 1600:	learn: 0.0307841	test: 0.0329579	best: 0.0329579 (1600)	total: 1m 9s	remaining: 17.3s
# 1800:	learn: 0.0302672	test: 0.0326457	best: 0.0326457 (1800)	total: 1m 18s	remaining: 8.62s
# 1999:	learn: 0.0298131	test: 0.0324228	best: 0.0324228 (1999)	total: 1m 26s	remaining: 0us
#
# bestTest = 0.03242283094
# bestIteration = 1999
#
#
# --- LightGBM ---
# Training until validation scores don't improve for 100 rounds
# [200]	train's rmse: 0.023615	val's rmse: 0.0297455
# [400]	train's rmse: 0.0201277	val's rmse: 0.0289931
# [600]	train's rmse: 0.017919	val's rmse: 0.0287026
# [800]	train's rmse: 0.0161855	val's rmse: 0.0285481
# [1000]	train's rmse: 0.0148087	val's rmse: 0.0284601
# [1200]	train's rmse: 0.0135862	val's rmse: 0.0284258
# Early stopping, best iteration is:
# [1191]	train's rmse: 0.0136368	val's rmse: 0.0284209
#
# --- XGBoost ---
# [0]	validation_0-rmse:0.13734
# [200]	validation_0-rmse:0.04543
# [400]	validation_0-rmse:0.04002
# [600]	validation_0-rmse:0.03705
# [800]	validation_0-rmse:0.03522
# [1000]	validation_0-rmse:0.03409
# [1200]	validation_0-rmse:0.03320
# [1400]	validation_0-rmse:0.03259
# [1600]	validation_0-rmse:0.03211
# [1800]	validation_0-rmse:0.03172
# [1999]	validation_0-rmse:0.03145
#
#   Fold 5 Summary:
#     CatBoost  -> RMSE: 0.032423 | R2: 0.948703
#     LightGBM  -> RMSE: 0.028421 | R2: 0.960585
#     XGBoost   -> RMSE: 0.031452 | R2: 0.951729
#
# ======================================================================
#   5-FOLD CROSS-VALIDATION COMPLETE
# ======================================================================

# %% [markdown]
# ## 5. Cross-Validation Results Summary

# %%
# Per-fold results table
metrics_df = pd.DataFrame(fold_metrics)
print("Per-Fold Results:")
print(metrics_df.to_string(index=False, float_format='%.6f'))

# Overall OOF metrics (computed on ALL out-of-fold predictions)
cat_oof_rmse = np.sqrt(mean_squared_error(y, oof_cat))
lgb_oof_rmse = np.sqrt(mean_squared_error(y, oof_lgb))
xgb_oof_rmse = np.sqrt(mean_squared_error(y, oof_xgb))

cat_oof_r2 = r2_score(y, oof_cat)
lgb_oof_r2 = r2_score(y, oof_lgb)
xgb_oof_r2 = r2_score(y, oof_xgb)

print("\n" + "="*60)
print("        OVERALL OOF METRICS (5-Fold CV)")
print("="*60)
print(f"  CatBoost   ->  RMSE: {cat_oof_rmse:.6f}  |  R2: {cat_oof_r2:.6f}")
print(f"  LightGBM   ->  RMSE: {lgb_oof_rmse:.6f}  |  R2: {lgb_oof_r2:.6f}")
print(f"  XGBoost    ->  RMSE: {xgb_oof_rmse:.6f}  |  R2: {xgb_oof_r2:.6f}")
print("="*60)
# Out:
# Per-Fold Results:
#  fold  cat_rmse   cat_r2  lgb_rmse   lgb_r2  xgb_rmse   xgb_r2
#     1  0.031981 0.949455  0.028129 0.960896  0.031517 0.950910
#     2  0.033146 0.947749  0.028918 0.960227  0.032409 0.950047
#     3  0.031583 0.950521  0.028407 0.959971  0.031206 0.951693
#     4  0.032659 0.944371  0.029390 0.954950  0.032688 0.944272
#     5  0.032423 0.948703  0.028421 0.960585  0.031452 0.951729
#
# ============================================================
#         OVERALL OOF METRICS (5-Fold CV)
# ============================================================
#   CatBoost   ->  RMSE: 0.032363  |  R2: 0.948197
#   LightGBM   ->  RMSE: 0.028657  |  R2: 0.959382
#   XGBoost    ->  RMSE: 0.031860  |  R2: 0.949795
# ============================================================

# %% [markdown]
# ## 6. Ensemble - Weighted Average (using OOF RMSE)

# %%
# Weights: inverse OOF RMSE (lower error -> higher weight)
w_cat = 1 / cat_oof_rmse
w_lgb = 1 / lgb_oof_rmse
w_xgb = 1 / xgb_oof_rmse
total = w_cat + w_lgb + w_xgb
w_cat, w_lgb, w_xgb = w_cat / total, w_lgb / total, w_xgb / total

print(f"Ensemble Weights -> CatBoost: {w_cat:.4f} | LightGBM: {w_lgb:.4f} | XGBoost: {w_xgb:.4f}")

# OOF ensemble
oof_ensemble = w_cat * oof_cat + w_lgb * oof_lgb + w_xgb * oof_xgb
ens_oof_rmse = np.sqrt(mean_squared_error(y, oof_ensemble))
ens_oof_r2 = r2_score(y, oof_ensemble)

print("\n" + "="*60)
print("            FINAL MODEL COMPARISON (5-Fold CV)")
print("="*60)
print(f"  CatBoost               ->  RMSE: {cat_oof_rmse:.6f}  |  R2: {cat_oof_r2:.6f}")
print(f"  LightGBM               ->  RMSE: {lgb_oof_rmse:.6f}  |  R2: {lgb_oof_r2:.6f}")
print(f"  XGBoost                ->  RMSE: {xgb_oof_rmse:.6f}  |  R2: {xgb_oof_r2:.6f}")
print("-"*60)
print(f"  ENSEMBLE (3-model, CV) ->  RMSE: {ens_oof_rmse:.6f}  |  R2: {ens_oof_r2:.6f}")
print("="*60)
# Out:
# Ensemble Weights -> CatBoost: 0.3180 | LightGBM: 0.3591 | XGBoost: 0.3230
#
# ============================================================
#             FINAL MODEL COMPARISON (5-Fold CV)
# ============================================================
#   CatBoost               ->  RMSE: 0.032363  |  R2: 0.948197
#   LightGBM               ->  RMSE: 0.028657  |  R2: 0.959382
#   XGBoost                ->  RMSE: 0.031860  |  R2: 0.949795
# ------------------------------------------------------------
#   ENSEMBLE (3-model, CV) ->  RMSE: 0.029359  |  R2: 0.957367
# ============================================================

# %% [markdown]
# ## 7. Feature Importance (from last fold's LightGBM model)

# %%
importance = pd.DataFrame({
    'feature': feature_cols,
    'importance': lgb_model.feature_importance(importance_type='gain')
}).sort_values('importance', ascending=False)

print("LightGBM Feature Importance (gain):")
print(importance.to_string(index=False))
# Out:
# LightGBM Feature Importance (gain):
#             feature  importance
#            RoadType 7179.213390
#             geohash 1502.151527
#           time_slot  245.902560
#            hour_sin  166.083317
#                hour  145.133101
#    dist_from_center  124.948026
# lat_lon_interaction  117.420586
#            latitude  110.457947
#            hour_cos  107.066720
#         gh_prefix_5  106.963406
#           longitude  103.728979
#       NumberofLanes   94.064225
#         Temperature   90.619494
#                 day   37.932313
#         lon_squared   26.341823
#              minute   18.410687
#       LargeVehicles   14.848825
#         lat_squared   11.986832
#           Landmarks    9.197732
#     spatial_cluster    5.409005
#             is_peak    5.083085
#             Weather    2.549201
#         gh_prefix_4    0.290357
#         gh_prefix_3    0.000000

# %% [markdown]
# ## 8. Predict on Test and Save

# %%
# Test predictions are already averaged across 5 folds
ensemble_test_pred = w_cat * test_cat + w_lgb * test_lgb + w_xgb * test_xgb

submission = pd.DataFrame({
    'Index': test_processed['Index'].astype(int),
    'demand': ensemble_test_pred
})

submission.to_csv("prediction.csv", index=False)
print(f"Saved prediction.csv - {len(submission)} rows")
submission.head()
# Out:
# Saved prediction.csv - 41778 rows
#    Index    demand
# 0      0  0.046658
# 1      1  0.025038
# 2      2  0.012175
# 3      3  0.027122
# 4      4  0.055285
